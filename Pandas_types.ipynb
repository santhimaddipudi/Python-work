# %% [markdown]
# <a href="https://colab.research.google.com/github/santhimaddipudi/Python/blob/master/Pandas_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#It is built on top of NumPy and provides features not available in it.
#There are three main data structures in pandas:
• Series
• DataFrame
• Panel###

# %% [markdown]
# ### Series

# %%
#series--1D array under the hood--dat acane be an ndarray,dict or scalar value
import numpy as np
import pandas as pd
np.random.seed(100)
ser=pd.Series(np.random.rand(7)); ser
# Out:
# 0    0.543405
# 1    0.278369
# 2    0.424518
# 3    0.844776
# 4    0.004719
# 5    0.121569
# 6    0.670749
# dtype: float64

# %%
#creates a Series structure of the first 5 months of the year with a specified index of month names
import calendar as cal
monthNames=[cal.month_name[i] for i in np.arange(1,6)]
months=pd.Series(np.arange(1,6),index=monthNames);months
# Out:
# January     1
# February    2
# March       3
# April       4
# May         5
# dtype: int64

# %%
#using dict for series
currDict={'US' : 'dollar', 'UK' : 'pound',
'Germany': 'euro', 'Mexico':'peso',
'Nigeria':'naira',
'China':'yuan', 'Japan':'yen'}
currSeries=pd.Series(currDict); currSeries
# Out:
# US         dollar
# UK          pound
# Germany      euro
# Mexico       peso
# Nigeria     naira
# China        yuan
# Japan         yen
# dtype: object

# %%
stockPrices = {'GOOG':1180.97,'FB':62.57,
'TWTR': 64.50, 'AMZN':358.69,
'AAPL':500.6}
stockPriceSeries=pd.Series(stockPrices,
index=['GOOG','FB','YHOO',
'TWTR','AMZN','AAPL'],
name='stockPrices')  #as the key for one of the index not availble in dict it is showing Nan
stockPriceSeries
# Out:
# GOOG    1180.97
# FB        62.57
# YHOO        NaN
# TWTR      64.50
# AMZN     358.69
# AAPL     500.60
# Name: stockPrices, dtype: float64

# %%
#using scalr values in series
dogSeries=pd.Series('chihuahua',
index=['breed','countryOfOrigin',
'name', 'gender'])
dogSeries
# Out:
# breed              chihuahua
# countryOfOrigin    chihuahua
# name               chihuahua
# gender             chihuahua
# dtype: object

# %%
type(dogSeries)
# Out:
# pandas.core.series.Series

# %%
dog2=pd.Series('chihuahua')#without index
dog2
type(dog2)
# Out:
# pandas.core.series.Series

# %%
stockPriceSeries
# Out:
# GOOG    1180.97
# FB        62.57
# YHOO        NaN
# TWTR      64.50
# AMZN     358.69
# AAPL     500.60
# Name: stockPrices, dtype: float64

# %%
stockPriceSeries['MSFT']# KeyError is raised if you try to retrieve a missing label

# %%
#alternative
stockPriceSeries.get('MSFT',np.NaN)
# Out:
# nan

# %%
stockPriceSeries[1:3]
# Out:
# FB      62.57
# YHOO      NaN
# Name: stockPrices, dtype: float64

# %%
stockPriceSeries[stockPriceSeries > 100]
# Out:
# GOOG    1180.97
# AMZN     358.69
# AAPL     500.60
# Name: stockPrices, dtype: float64

# %%
#statistical operations
print(np.mean(stockPriceSeries))
print(np.std(stockPriceSeries))
# Out:
# 433.466
# 410.50223047384287

# %%
ser
# Out:
# 0    0.543405
# 1    0.278369
# 2    0.424518
# 3    0.844776
# 4    0.004719
# 5    0.121569
# 6    0.670749
# dtype: float64

# %%
ser*ser
# Out:
# 0    0.295289
# 1    0.077490
# 2    0.180215
# 3    0.713647
# 4    0.000022
# 5    0.014779
# 6    0.449904
# dtype: float64

# %%
#data is automatically aligned on the basis of the label
ser[1:]+ser[:-3]
# Out:
# 0         NaN
# 1    0.556739
# 2    0.849035
# 3    1.689552
# 4         NaN
# 5         NaN
# 6         NaN
# dtype: float64

# %% [markdown]
# ### **DataFrame**
# DataFrame is an 2-dimensional labeled array. Its column types can be heterogeneous:
# that is, of varying types.

# %%
#create a DataFrame structure by using a dictionary of Series objects.
import pandas as pd
stockSummaries={
'AMZN': pd.Series([346.15,0.59,459,0.52,589.8,158.88],
index=['Closing price','EPS',
'Shares Outstanding(M)',
'Beta', 'P/E','Market Cap(B)']),
'GOOG': pd.Series([1133.43,36.05,335.83,0.87,31.44,380.64],
index=['Closing price','EPS','Shares Outstanding(M)',
'Beta','P/E','Market Cap(B)']),
'FB': pd.Series([61.48,0.59,2450,104.93,150.92],
index=['Closing price','EPS','Shares Outstanding(M)',
'P/E', 'Market Cap(B)']),
'YHOO': pd.Series([34.90,1.27,1010,27.48,0.66,35.36],
index=['Closing price','EPS','Shares Outstanding(M)',
'P/E','Beta', 'Market Cap(B)']),
'TWTR':pd.Series([65.25,-0.3,555.2,36.23],
index=['Closing price','EPS','Shares Outstanding(M)',
'Market Cap(B)']),
'AAPL':pd.Series([501.53,40.32,892.45,12.44,447.59,0.84],
index=['Closing price','EPS','Shares Outstanding(M)','P/E',
'Market Cap(B)','Beta'])}
stockDF=pd.DataFrame(stockSummaries)
stockDF
# Out:
#                          AMZN     GOOG       FB     YHOO    TWTR    AAPL
# Beta                     0.52     0.87      NaN     0.66     NaN    0.84
# Closing price          346.15  1133.43    61.48    34.90   65.25  501.53
# EPS                      0.59    36.05     0.59     1.27   -0.30   40.32
# Market Cap(B)          158.88   380.64   150.92    35.36   36.23  447.59
# P/E                    589.80    31.44   104.93    27.48     NaN   12.44
# Shares Outstanding(M)  459.00   335.83  2450.00  1010.00  555.20  892.45

# %%
#row index labels and column labels can be accessed via the index and column attributes
stockDF=pd.DataFrame(stockSummaries,
index=['Closing price','EPS',
'Shares Outstanding(M)',
'P/E', 'Market Cap(B)','Beta'],
columns=['FB','TWTR','SCNW'])
stockDF
# Out:
#                             FB    TWTR SCNW
# Closing price            61.48   65.25  NaN
# EPS                       0.59   -0.30  NaN
# Shares Outstanding(M)  2450.00  555.20  NaN
# P/E                     104.93     NaN  NaN
# Market Cap(B)           150.92   36.23  NaN
# Beta                       NaN     NaN  NaN

# %%
print(stockDF.index)
print(stockDF.columns)
# Out:
# Index(['Closing price', 'EPS', 'Shares Outstanding(M)', 'P/E', 'Market Cap(B)',
#        'Beta'],
#       dtype='object')
# Index(['FB', 'TWTR', 'SCNW'], dtype='object')

# %%
#create a DataFrame structure from a dictionary of lists. The keys become the column labels  data in the list becomes the column values.
algos={
    'search':['DFS','BFS','Binary Search','Linear','ShortestPath (Djikstra)'],
    'sorting': ['Quicksort','Mergesort', 'Heapsort','Bubble Sort', 'Insertion Sort'],
    'machine learning':['RandomForest','K Nearest Neighbor','Logistic Regression','K-Means Clustering','Linear Regression']
    }
algoDF=pd.DataFrame(algos); algoDF
# Out:
#                     search         sorting     machine learning
# 0                      DFS       Quicksort         RandomForest
# 1                      BFS       Mergesort   K Nearest Neighbor
# 2            Binary Search        Heapsort  Logistic Regression
# 3                   Linear     Bubble Sort   K-Means Clustering
# 4  ShortestPath (Djikstra)  Insertion Sort    Linear Regression

# %%
pd.DataFrame(algos,index=['algo_1','algo_2','algo_3','algo_4','algo_5'])
# Out:
#                          search         sorting     machine learning
# algo_1                      DFS       Quicksort         RandomForest
# algo_2                      BFS       Mergesort   K Nearest Neighbor
# algo_3            Binary Search        Heapsort  Logistic Regression
# algo_4                   Linear     Bubble Sort   K-Means Clustering
# algo_5  ShortestPath (Djikstra)  Insertion Sort    Linear Regression

# %%
algoDF=pd.DataFrame(algos,index=['algo_1','algo_2','algo_3','algo_4','algo_5'])

# %%
algoDF
# Out:
#                          search         sorting     machine learning
# algo_1                      DFS       Quicksort         RandomForest
# algo_2                      BFS       Mergesort   K Nearest Neighbor
# algo_3            Binary Search        Heapsort  Logistic Regression
# algo_4                   Linear     Bubble Sort   K-Means Clustering
# algo_5  ShortestPath (Djikstra)  Insertion Sort    Linear Regression

# %%
#we use a structured array to create a data frame
import numpy as np
memberData = np.zeros((5,),
dtype=[('Name','a15'),
('Age','i4'),
('Weight','f4')])
memberData[:] = [('Sanjeev',37,162.4),
('Yingluck',45,137.8),
('Emeka',28,153.2),
('Amy',67,101.3),
('santhi',65,22.4)
]
memberDF=pd.DataFrame(memberData);memberDF
# Out:
#           Name  Age      Weight
# 0   b'Sanjeev'   37  162.399994
# 1  b'Yingluck'   45  137.800003
# 2     b'Emeka'   28  153.199997
# 3       b'Amy'   67  101.300003
# 4    b'santhi'   65   22.400000

# %% [markdown]
# ###Dataframe operations

# %%
memberDF['Name']
# Out:
# 0     b'Sanjeev'
# 1    b'Yingluck'
# 2       b'Emeka'
# 3         b'Amy'
# 4      b'santhi'
# Name: Name, dtype: object

# %%
memberDF['Height']=40 #add a new column
memberDF
# Out:
#           Name  Age      Weight  Height
# 0   b'Sanjeev'   37  162.399994      40
# 1  b'Yingluck'   45  137.800003      40
# 2     b'Emeka'   28  153.199997      40
# 3       b'Amy'   67  101.300003      40
# 4    b'santhi'   65   22.400000      40

# %%
del memberDF['Height']
memberDF
# Out:
#           Name  Age      Weight
# 0   b'Sanjeev'   37  162.399994
# 1  b'Yingluck'   45  137.800003
# 2     b'Emeka'   28  153.199997
# 3       b'Amy'   67  101.300003
# 4    b'santhi'   65   22.400000

# %%
memberDF['BloodType']='O'
memberDF
bloodType=memberDF.pop('BloodType'); bloodType #pop column from DF
# Out:
# 0    O
# 1    O
# 2    O
# 3    O
# 4    O
# Name: BloodType, dtype: object

# %%
#insert a column at a specific location
memberDF.insert(2,'isSenior',memberDF['Age']>60);
memberDF
# Out:
#           Name  Age  isSenior      Weight
# 0   b'Sanjeev'   37     False  162.399994
# 1  b'Yingluck'   45     False  137.800003
# 2     b'Emeka'   28     False  153.199997
# 3       b'Amy'   67      True  101.300003
# 4    b'santhi'   65      True   22.400000

# %%
#In the case where there are no row labels or column labels in common, the value is filled with NaN
#default behavior is to broadcast the Series object across the rows
ore1DF=pd.DataFrame(np.array([[20,35,25,20],
                             [11,28,32,29]]),
                    columns=['iron','magnesium','copper','silver'])
print(ore1DF)
ore2DF=pd.DataFrame(np.array([[14,34,26,26],
                            [33,19,25,23]]),
                  columns=['iron','magnesium','gold','silver'])
print(ore2DF)
ore1DF+ore2DF
# Out:
#    iron  magnesium  copper  silver
# 0    20         35      25      20
# 1    11         28      32      29
#    iron  magnesium  gold  silver
# 0    14         34    26      26
# 1    33         19    25      23
#    copper  gold  iron  magnesium  silver
# 0     NaN   NaN    34         69      46
# 1     NaN   NaN    44         47      52

# %%
ore1DF + pd.Series([25,25,25,25],
index=['iron','magnesium',
'copper','silver'])
# Out:
#    iron  magnesium  copper  silver
# 0    45         60      50      45
# 1    36         53      57      54

# %% [markdown]
# **###Panel**: Panel is a 3D array. It is not as widely used as Series or DataFrame. It is not as easily
# displayed on screen or visualized as the other two because of its 3D nature.
#
# The three axis names are as follows:
#
# •** items**: This is axis 0. Each each item corresponds to a DataFrame structure.
#
# •** major_axis**: This is axis 1. Each item corresponds to the rows of the
# DataFrame structure.
#
# •** minor_axis**: This is axis 2. Each item corresponds to the columns of each
# DataFrame structure.

# %%
#construct a Panel object from a 3D NumPy array
stockData=np.array([[[63.03,61.48,75],
[62.05,62.75,46],
[62.74,62.19,53]],
[[411.90, 404.38, 2.9],
[405.45, 405.91, 2.6],
[403.15, 404.42, 2.4]]])
print("numpy array:",stockData)
stockHistoricalPrices = pd.Panel(stockData,
                                 items=['FB', 'NFLX'],
                                 major_axis=pd.date_range('2/3/2014',periods=3),
                                 minor_axis=['open price', 'closing price', 'volume'])
stockHistoricalPrices
